# %% [markdown]
# #housing price prediction project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv("housing.csv")

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# price is the y for us here means it is used for price prediction whereas other other attributes are varibales /data points

# %%
#data preprocessing

# %%
# we are converting all the categorical variables for model in numerical

# %%
#yes/no columns into 1 or 0

# %%
binary_cols=[
    'mainroad',
    'guestroom',
    'basement',
    'hotwaterheating',
    'airconditioning',
    'prefarea',
    'furnishingstatus'
]

for col in binary_cols:
    data[col]=data[col].map({'yes':1,'no':0})

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
#funished stauts

# %%
data=pd.get_dummies(data,
                    columns=['furnishingstatus'],
                    drop_first=True)

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea
# ...

# %%
#build the model

# %%
x=data.drop('price',axis=1)
y=data['price']

# %%
#ml library

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(
    x,y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([5398919.06668406, 7065403.52242257, 2993803.65442489,
#        4535814.37095637, 3053270.46119634, 3709351.46814548,
#        5440532.08436119, 6228231.2637049 , 2882007.07052161,
#        2341077.46202216, 9669446.99384903, 2968606.34038989,
#        3313473.96276161, 3298076.7146539 , 3917562.61502005,
#        5451316.51696925, 2935783.76577867, 5020968.01587435,
#        4611901.50853052, 3459716.25356269, 6031175.37726022,
#        5858126.13664539, 2900858.8451071 , 5004989.10270268,
#        5250383.45099946, 7582448.67436233, 3446590.61322786,
#        5039916.00815844, 8051720.01234679, 3173494.27554285,
#        6479223.19419278, 3527946.31942094, 6553367.01960289,
#        4111301.41589294, 3752397.72547943, 5797499.44418857,
#        4816747.63555382, 4616670.38819151, 3334907.08797079,
#        4389155.37405231, 4503752.98075596, 3704757.77375415,
#        7046386.68164143, 3784673.66996625, 3637999.13588582,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
print("R2 score :", r2_score(y_test,y_pred))
print("MAE: " , mean_absolute_error(y_test,y_pred))
# Out:
# R2 score : 0.6437296086614115
# MAE:  979112.2162187377
