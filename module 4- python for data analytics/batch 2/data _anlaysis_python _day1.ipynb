# %%
# load libraries

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("coffee_sales.csv")

# %%
data
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3636 non-null   object
#  1   datetime     3636 non-null   object
#  2   cash_type    3636 non-null   object
#  3   card         3547 non-null   object
#  4   money        3636 non-null   float64
#  5   coffee_name  3636 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 170.6+ KB

# %%
data.describe()
# Out:
#              money
# count  3636.000000
# mean     31.746859
# std       4.919926
# min      18.120000
# 25%      27.920000
# 50%      32.820000
# 75%      35.760000
# max      40.000000

# %%
data.head() # to see first 5 rows of data
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
data.tail() # to see last five rows of data
# Out:
#             date                 datetime cash_type                 card  \
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money coffee_name
# 3631  35.76  Cappuccino
# 3632  35.76       Cocoa
# 3633  35.76       Cocoa
# 3634  25.96   Americano
# 3635  35.76       Latte

# %%
data.shape # columns and rows in the data
# Out:
# (3636, 6)

# %%
# data cleaning

# %%
# checling the missing values

# %%
data.isna().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
data['card']
# Out:
# 0       ANON-0000-0000-0001
# 1       ANON-0000-0000-0002
# 2       ANON-0000-0000-0002
# 3       ANON-0000-0000-0003
# 4       ANON-0000-0000-0004
#                ...
# 3631    ANON-0000-0000-1158
# 3632    ANON-0000-0000-1315
# 3633    ANON-0000-0000-1315
# 3634    ANON-0000-0000-1316
# 3635    ANON-0000-0000-1275
# Name: card, Length: 3636, dtype: object

# %%
# how to see the full data

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
print(data)
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# 5     2024-03-01  2024-03-01 15:39:47.726      card  ANON-0000-0000-0005
# 6     2024-03-01  2024-03-01 16:19:02.756      card  ANON-0000-0000-0006
# 7     2024-03-01  2024-03-01 18:39:03.580      card  ANON-0000-0000-0007
# 8     2024-03-01  2024-03-01 19:22:01.762      card  ANON-0000-0000-0008
# 9     2024-03-01  2024-03-01 19:23:15.887      card  ANON-0000-0000-0008
# 10    2024-03-01  2024-03-01 19:29:17.391      card  ANON-0000-0000-0009
# 11    2024-03-02  2024-03-02 10:22:06.957      card  ANON-0000-0000-0010
# ...

# %%
# fill the missing values in card column

# %%
data['card']=data['card'].fillna("payement in cash ")

# %%
data
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# 5     2024-03-01  2024-03-01 15:39:47.726      card  ANON-0000-0000-0005
# 6     2024-03-01  2024-03-01 16:19:02.756      card  ANON-0000-0000-0006
# 7     2024-03-01  2024-03-01 18:39:03.580      card  ANON-0000-0000-0007
# 8     2024-03-01  2024-03-01 19:22:01.762      card  ANON-0000-0000-0008
# 9     2024-03-01  2024-03-01 19:23:15.887      card  ANON-0000-0000-0008
# 10    2024-03-01  2024-03-01 19:29:17.391      card  ANON-0000-0000-0009
# 11    2024-03-02  2024-03-02 10:22:06.957      card  ANON-0000-0000-0010
# ...

# %%
# data duplicate

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, datetime, cash_type, card, money, coffee_name]
# Index: []

# %%
# to check duplicate for specific column

# %%
data[data.duplicated(subset=["card"] , keep=False)]
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# 8     2024-03-01  2024-03-01 19:22:01.762      card  ANON-0000-0000-0008
# 9     2024-03-01  2024-03-01 19:23:15.887      card  ANON-0000-0000-0008
# 10    2024-03-01  2024-03-01 19:29:17.391      card  ANON-0000-0000-0009
# 12    2024-03-02  2024-03-02 10:30:35.668      cash    payement in cash
# 14    2024-03-02  2024-03-02 11:59:45.484      card  ANON-0000-0000-0012
# 17    2024-03-02  2024-03-02 17:34:54.969      card  ANON-0000-0000-0004
# 18    2024-03-03  2024-03-03 10:10:43.981      cash    payement in cash
# ...

# %%
# remove the duplicates

# %%
##data=data.drop_duplicated()

# %%
# basic analysis

# %%
data.columns
# Out:
# Index(['date', 'datetime', 'cash_type', 'card', 'money', 'coffee_name'], dtype='object')

# %%
data.nunique()
# Out:
# date            381
# datetime       3636
# cash_type         2
# card           1317
# money            20
# coffee_name       8
# dtype: int64

# %%
# frequency of coffee by each category

# %%
data['cash_type'].value_counts() # value-count is used to count the frequency
# Out:
# cash_type
# card    3547
# cash      89
# Name: count, dtype: int64

# %%
# frequency of coffee name

# %%
data['coffee_name'].value_counts()
# Out:
# coffee_name
# Americano with Milk    824
# Latte                  782
# Americano              578
# Cappuccino             501
# Cortado                292
# Hot Chocolate          282
# Cocoa                  243
# Espresso               134
# Name: count, dtype: int64

# %%
# sorting data

# %%
# by deafult sorting is descending

# %%
data.sort_values(by="money", ascending =False)
# Out:
#             date                 datetime cash_type                 card  \
# 60    2024-03-09  2024-03-09 11:49:37.292      cash    payement in cash
# 117   2024-03-15  2024-03-15 10:02:16.533      cash    payement in cash
# 126   2024-03-17  2024-03-17 10:10:21.399      cash    payement in cash
# 225   2024-04-04  2024-04-04 19:42:07.740      cash    payement in cash
# 264   2024-04-10  2024-04-10 17:55:07.018      cash    payement in cash
# 152   2024-03-22  2024-03-22 16:15:14.448      cash    payement in cash
# 232   2024-04-05  2024-04-05 15:30:50.383      cash    payement in cash
# 233   2024-04-05  2024-04-05 15:54:15.768      cash    payement in cash
# 76    2024-03-10  2024-03-10 10:06:02.960      cash    payement in cash
# 235   2024-04-05  2024-04-05 16:17:43.975      cash    payement in cash
# 311   2024-04-17  2024-04-17 16:13:24.310      cash    payement in cash
# 164   2024-03-24  2024-03-24 10:03:56.005      cash    payement in cash
# ...
